# %%
import pandas as pd

# Load your CSV file
data = pd.read_csv('clustered_testing_data_fixed_10_clusters.csv')

# Calculate the centroids (mean values) for each cluster
centroids = data.groupby('cluster').mean()

# Extract relevant features for centroid calculation
centroids = centroids[['traveled_distance_pixel', 'elapsed_time', 'straightness', 
                       'direction_of_movement', 'mean_a', 'mean_jerk']]

pd.set_option('display.float_format', lambda x: '%.6f' % x)

# Optionally, round the acceleration and jerk values to a fixed number of decimal places
data['mean_a'] = data['mean_a'].round(6)
data['mean_jerk'] = data['mean_jerk'].round(6)

# Now display the data without scientific notation
print(data.head(10))
centroids
# Out:
#    type_of_action  traveled_distance_pixel  elapsed_time  \
# 0               3               357.084960      1.170000
# 1               3               369.966397      1.591000
# 2               3               993.948298      6.849000
# 3               1              1610.385871      4.431000
# 4               3               305.408959      0.780000
# 5               3               811.867335      4.509000
# 6               3                59.508061      0.483000
# 7               3               785.563197      3.151000
# 8               3                97.718998      0.748000
# 9               3               259.766484      0.983000
#
#    direction_of_movement  straightness  num_points  sum_of_angles  mean_curv  \
# 0                      7      0.519784          10       3.697425  -0.090787
# 1                      6      0.606582          14       5.039419   0.079153
# 2                      1      0.787196          19      -0.545368   0.209308
# 3                      4      0.409789          27     -24.136770   0.207996
# 4                      2      0.954445           7      12.897938   0.011900
# 5                      6      0.358604          35     -14.956365   0.276088
# 6                      1      0.855873           6       7.005020   0.170279
# 7                      0      0.145865          16     -18.778410  -0.003891
# 8                      6      0.966991           7      -5.134537  -0.014187
# 9                      2      0.794868           9      -2.498936  -0.049585
#
#    sd_curv  max_curv  ...       max_jerk       min_jerk  a_beg_time  class  \
# 0 0.267935  0.177068  ...   63514.284450  -64410.624680    0.218000     12
# 1 0.298541  0.999899  ...   61866.820730 -135966.877600    0.219000     12
# 2 0.546451  2.205236  ...  192558.645000 -279489.768600    0.172000     12
# 3 1.614762  4.805866  ... 1822710.331000 -496593.124500    0.219000     12
# 4 0.010247  0.028614  ...  138413.312500 -255781.590000    0.110000     12
# 5 1.288380  5.695183  ...  137015.925800 -268753.850300    0.328000     12
# 6 0.357545  0.714017  ...   27604.165040  -18833.929610    0.093000     12
# 7 0.012092  0.008659  ...  147437.264800 -159391.446500    1.466000     12
# 8 0.031076  0.011473  ...   92431.228610 -100190.309800    0.078000     12
# 9 0.148895  0.020605  ...  148710.153400 -176681.818400    0.093000     12
#
#      session  n_from  n_to   islegal  cluster  distance_to_center
# 0  126772600       5    15         0        8            0.458813
# 1  126772600      16    30         0        8            0.345528
# 2  126772600      31    50         0        6            0.695502
# 3  126772600      51    77         0        0            0.728013
# 4  126772600      82    91         0        6            0.992084
# 5  126772600      92   128         0        8            0.423058
# 6  126772600     129   136         0        6            0.497070
# 7  126772600     137   154         0        6            0.532907
# 8  126772600     155   163         0        8            0.413742
# 9  126772600     164   174         0        6            0.772693
#
# [10 rows x 46 columns]
#          traveled_distance_pixel  elapsed_time  straightness  \
# cluster
# 0                     641.363865      2.990479      0.659282
# 1                    2224.938973      1.235400      0.538565
# 2                    3218.138560      3.100000      0.248072
# 3                    2273.796898      5.033774      0.488202
# 4                    4299.961719      6.979969      0.199630
# 5                    2632.284931      3.350407      0.489522
# 6                     507.525532      2.735236      0.678240
# 7                    1287.499811      3.075068      0.604634
# 8                     621.059417      2.928159      0.645718
# 9                    2593.142108      3.805083      0.317067
#
#          direction_of_movement         mean_a        mean_jerk
# cluster
# 0                     3.592386    5288.491483    475738.902742
# 1                     3.400000 1935935.947200 197512543.680000
# 2                     2.214286  293255.014434 -30475434.310571
# 3                     3.603015  271774.452772  20681149.819074
# 4                     3.375000  275783.372867  -8095677.904919
# 5                     4.222222  674571.609167  57771958.331505
# 6                     0.866880    4654.816770    416704.603480
# 7                     3.753377   94408.614577   8912805.450347
# 8                     6.047513    4733.489154    420310.441115
# 9                     2.270833  579666.330165  51016239.294458

# %%
import pandas as pd

# Load your CSV file
data = pd.read_csv('clustered_testing_data_fixed_10_clusters.csv')

# Calculate the centroids (mean values) for each cluster
centroids = data.groupby('cluster').median()

# Extract relevant features for centroid calculation
centroids = centroids[['traveled_distance_pixel', 'elapsed_time', 'straightness', 
                       'direction_of_movement', 'mean_a', 'mean_jerk']]

pd.set_option('display.float_format', lambda x: '%.6f' % x)

# Optionally, round the acceleration and jerk values to a fixed number of decimal places
data['mean_a'] = data['mean_a'].round(6)
data['mean_jerk'] = data['mean_jerk'].round(6)

# Now display the data without scientific notation
print(data.head(10))
centroids
# Out:
#    type_of_action  traveled_distance_pixel  elapsed_time  \
# 0               3               357.084960      1.170000
# 1               3               369.966397      1.591000
# 2               3               993.948298      6.849000
# 3               1              1610.385871      4.431000
# 4               3               305.408959      0.780000
# 5               3               811.867335      4.509000
# 6               3                59.508061      0.483000
# 7               3               785.563197      3.151000
# 8               3                97.718998      0.748000
# 9               3               259.766484      0.983000
#
#    direction_of_movement  straightness  num_points  sum_of_angles  mean_curv  \
# 0                      7      0.519784          10       3.697425  -0.090787
# 1                      6      0.606582          14       5.039419   0.079153
# 2                      1      0.787196          19      -0.545368   0.209308
# 3                      4      0.409789          27     -24.136770   0.207996
# 4                      2      0.954445           7      12.897938   0.011900
# 5                      6      0.358604          35     -14.956365   0.276088
# 6                      1      0.855873           6       7.005020   0.170279
# 7                      0      0.145865          16     -18.778410  -0.003891
# 8                      6      0.966991           7      -5.134537  -0.014187
# 9                      2      0.794868           9      -2.498936  -0.049585
#
#    sd_curv  max_curv  ...       max_jerk       min_jerk  a_beg_time  class  \
# 0 0.267935  0.177068  ...   63514.284450  -64410.624680    0.218000     12
# 1 0.298541  0.999899  ...   61866.820730 -135966.877600    0.219000     12
# 2 0.546451  2.205236  ...  192558.645000 -279489.768600    0.172000     12
# 3 1.614762  4.805866  ... 1822710.331000 -496593.124500    0.219000     12
# 4 0.010247  0.028614  ...  138413.312500 -255781.590000    0.110000     12
# 5 1.288380  5.695183  ...  137015.925800 -268753.850300    0.328000     12
# 6 0.357545  0.714017  ...   27604.165040  -18833.929610    0.093000     12
# 7 0.012092  0.008659  ...  147437.264800 -159391.446500    1.466000     12
# 8 0.031076  0.011473  ...   92431.228610 -100190.309800    0.078000     12
# 9 0.148895  0.020605  ...  148710.153400 -176681.818400    0.093000     12
#
#      session  n_from  n_to   islegal  cluster  distance_to_center
# 0  126772600       5    15         0        8            0.458813
# 1  126772600      16    30         0        8            0.345528
# 2  126772600      31    50         0        6            0.695502
# 3  126772600      51    77         0        0            0.728013
# 4  126772600      82    91         0        6            0.992084
# 5  126772600      92   128         0        8            0.423058
# 6  126772600     129   136         0        6            0.497070
# 7  126772600     137   154         0        6            0.532907
# 8  126772600     155   163         0        8            0.413742
# 9  126772600     164   174         0        6            0.772693
#
# [10 rows x 46 columns]
#          traveled_distance_pixel  elapsed_time  straightness  \
# cluster
# 0                     411.448641      1.607000      0.745356
# 1                    2273.141629      1.185000      0.387322
# 2                    2937.466258      1.935000      0.276442
# 3                    1762.550618      2.200000      0.424169
# 4                    3930.849537      5.896500      0.129005
# 5                    2282.226190      1.607000      0.562923
# 6                     314.017569      1.466000      0.763621
# 7                     941.577816      1.576000      0.665793
# 8                     393.626963      1.591000      0.725515
# 9                    2117.150488      2.277500      0.270507
#
#          direction_of_movement         mean_a        mean_jerk
# cluster
# 0                     4.000000     709.386085      5523.584018
# 1                     4.000000 1901186.950000 203441265.800000
# 2                     2.500000   85958.024830 -36311176.765000
# 3                     3.000000  269711.606300  21804720.090000
# 4                     4.000000  279925.131200  -3014929.686000
# 5                     4.000000  632656.073900  57527136.550000
# 6                     1.000000     570.051423      3848.586433
# 7                     4.000000   81481.860650   7995421.015000
# 8                     6.000000     665.889019      4921.958442
# 9                     2.000000  571208.702350  48510435.635000
